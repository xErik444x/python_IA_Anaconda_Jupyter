# %%
import pandas as pd
import numpy as np
import matplotlib as pl

# %%
pagina_web = "https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n"

# %%
datos = pd.read_html(pagina_web)
datos[0]
# Out:
#        №                   País (o territorio dependiente)  \
# 0      1                                        China[13]​
# 1      2                                             India
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyecciónexponencialde lapoblaciónal1/7/2021[8]​  % deltotalmun-dial  \
# 0                                       1 416 687 000                1814
# 1                                       1 389 754 000                1779
# ...

# %%
dataframeCensos = pd.DataFrame(datos[0]["Censo másreciente,últimaestimaciónoficial,proyecciónde la ONUo reloj depoblaciónnacional"])
dataframePaises = pd.DataFrame(datos[0]["País (o territorio dependiente)"])
dataframeDatos = pd.concat([dataframePaises,dataframeCensos],axis=1)
dataframeDatos
# Out:
#                       País (o territorio dependiente)  \
# 0                                          China[13]​
# 1                                               India
# 2                                      Estados Unidos
# 3                                           Indonesia
# 4                                            Pakistán
# ..                                                ...
# 241                           Islas Cocos (Australia)
# 242  Islas Ultramarinas Menores de los Estados Unidos
# 243                               Islas Pitcairn (RU)
# 244                                             Mundo
# 245                   País (o territorio dependiente)
#
#     Censo másreciente,últimaestimaciónoficial,proyecciónde la ONUo reloj depoblaciónnacional
# 0                                        1 411 778 724
# 1                                        1 386 527 000
# 2                                          332 525 000
# 3                                          271 350 000
# ...

# %%
dict = {'País (o territorio dependiente)': 'Pais',
        'Censo másreciente,últimaestimaciónoficial,proyecciónde la ONUo reloj depoblaciónnacional': 'Censo'}
dataframeDatos.rename(columns=dict,inplace=True)

# %%
dataframeDatos
# Out:
#                                                  Pais  \
# 0                                          China[13]​
# 1                                               India
# 2                                      Estados Unidos
# 3                                           Indonesia
# 4                                            Pakistán
# ..                                                ...
# 241                           Islas Cocos (Australia)
# 242  Islas Ultramarinas Menores de los Estados Unidos
# 243                               Islas Pitcairn (RU)
# 244                                             Mundo
# 245                   País (o territorio dependiente)
#
#                                                  Censo
# 0                                        1 411 778 724
# 1                                        1 386 527 000
# 2                                          332 525 000
# 3                                          271 350 000
# ...

# %%
dataframeDatos.loc(["India"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-9acd5e436f55> in <module>
# ----> 1 dataframeDatos.loc(["India"])
#
# H:\programasparapython\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# H:\programasparapython\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'list'
